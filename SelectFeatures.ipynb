# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data = pd.read_csv("data/train.csv")
X = data.iloc[:,0:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range

# %%
bestfeatures = SelectKBest(score_func=chi2, k=10)

# %%
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)

# %%
dfcolumns = pd.DataFrame(X.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

# %%
featureScores.columns = ['Specs','Score']

# %%
print(featureScores.nlargest(10,'Score'))
# Out:
#             Specs          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data2 = pd.read_csv("../Classification/muffin-cupcake-master/recipes_muffins_cupcakes.csv")

# %%
data2.head(20)
# Out:
#        Type  Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt
# 0    Muffin     55    28      3       7    5              2        0     0
# 1    Muffin     47    24     12       6    9              1        0     0
# 2    Muffin     47    23     18       6    4              1        0     0
# 3    Muffin     45    11     17      17    8              1        0     0
# 4    Muffin     50    25     12       6    5              2        1     0
# 5    Muffin     55    27      3       7    5              2        1     0
# 6    Muffin     54    27      7       5    5              2        0     0
# 7    Muffin     47    26     10      10    4              1        0     0
# 8    Muffin     50    17     17       8    6              1        0     0
# 9    Muffin     50    17     17      11    4              1        0     0
# 10  Cupcake     39     0     26      19   14              1        1     0
# ...

# %%
X2 = data2.iloc[:,1:8]  #independent columns
y2 = data2.iloc[:,0]    #target column i.e price range
bestfeatures2 = SelectKBest(score_func=chi2, k=5)
fit2 = bestfeatures2.fit(X2,y2)
dfscores2 = pd.DataFrame(fit2.scores_)
dfcolumns2 = pd.DataFrame(X2.columns)
featureScores2 = pd.concat([dfcolumns2,dfscores2],axis=1)
featureScores2.columns = ['Specs','Score'] 
print(featureScores2.nlargest(5,'Score'))
# Out:
#     Specs      Score
# 2   Sugar  35.380117
# 0   Flour  16.952164
# 1    Milk  16.822102
# 3  Butter  13.254545
# 4     Egg   8.027778

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x, y = np.arange(400).reshape((200, 2)), range(5)
x.shape
# Out:
# (200, 2)

# %%
X_train, X_test = train_test_split(x, train_size=150, test_size=0.25)

# %%
X_train[0:5]
# Out:
# array([[328, 329],
#        [120, 121],
#        [ 68,  69],
#        [334, 335],
#        [226, 227]])

# %%
X_test[0:5]
# Out:
# array([[118, 119],
#        [206, 207],
#        [278, 279],
#        [124, 125],
#        [276, 277]])
